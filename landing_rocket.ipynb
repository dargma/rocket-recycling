# %%
# Google Drive 마운트
from google.colab import drive
import os

drive.mount('/content/drive')
# %cd /content/drive/MyDrive/rocket-recycling
print("현재 위치:", os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/rocket-recycling
# 현재 위치: /content/drive/MyDrive/rocket-recycling

# %%
# 관련 Package 설치
# !pip install pygame
# !pip install pyglet==1.5.27
# !apt-get install -y xvfb python-opengl > /dev/null
# !pip install pyvirtualdisplay

# Set up Virtual Display again
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()
print("Pygame and Virtual Display setup complete.")
# !pip -q uninstall -y pygame pygame-ce
# !pip -q install "pygame==2.5.2"
# Out:
# Requirement already satisfied: pygame in /usr/local/lib/python3.12/dist-packages (2.5.2)
# Requirement already satisfied: pyglet==1.5.27 in /usr/local/lib/python3.12/dist-packages (1.5.27)
# E: Unable to locate package python-opengl
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.12/dist-packages (3.0)
# Pygame and Virtual Display setup complete.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# WARNING: Skipping pygame-ce as it is not installed.

# %%
# !python example_train.py --task landing --max_m_episode 800000 --max_steps 800 --video_interval 8000
# Out:
# 🚀 Training Start! Task: landing, Device: cuda:0
# ⚙️  Settings: Episodes=800000, MaxSteps=800, VideoInterval=8000
# 🔄 Loading checkpoint: ./landing_ckpt/ckpt_00000100.pt
# episode id: 100, episode reward: -598.455
# 💾 Saved checkpoint: ./landing_ckpt/ckpt_00000100.pt
# episode id: 110, episode reward: -181.668
# episode id: 120, episode reward: -27.989
# episode id: 130, episode reward: -13.829
# episode id: 140, episode reward: -445.128
# episode id: 150, episode reward: 23.286
# episode id: 160, episode reward: 5.720
# episode id: 170, episode reward: -24.370
# episode id: 180, episode reward: -380.947
# episode id: 190, episode reward: 23.113
# episode id: 200, episode reward: -110.410
# 💾 Saved checkpoint: ./landing_ckpt/ckpt_00000200.pt
# episode id: 210, episode reward: -109.711
# episode id: 220, episode reward: -192.013
# episode id: 230, episode reward: -48.806
# episode id: 240, episode reward: 61.021
# episode id: 250, episode reward: 0.044
# object address  : 0x7e2f0201bbe0
# object refcount : 3
# object type     : 0xa2a4e0
# object type name: KeyboardInterrupt
# object repr     : KeyboardInterrupt()
# lost sys.stderr

# %%
# !python example_inference.py --task landing
# Out:
# 🚀 Inference Start! Task: landing, Device: cuda:0
# ➡️ Loading checkpoint: ./landing_ckpt/ckpt_00000200.pt
# --- 인퍼런스 진행 중... ---
# ✅ 인퍼런스 완료. 총 228 스텝.
# 💾 GIF 저장 중: ./landing_ckpt/inference_result.gif
# --- 인퍼런스 결과 GIF ---
# <IPython.core.display.HTML object>
